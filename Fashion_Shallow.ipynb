# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28,28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=10, validation_split=0.1, batch_size=128)
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.7189 - loss: 0.8038 - val_accuracy: 0.8470 - val_loss: 0.4394
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8456 - loss: 0.4385 - val_accuracy: 0.8572 - val_loss: 0.3916
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8585 - loss: 0.3960 - val_accuracy: 0.8692 - val_loss: 0.3583
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8714 - loss: 0.3618 - val_accuracy: 0.8738 - val_loss: 0.3452
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8750 - loss: 0.3467 - val_accuracy: 0.8665 - val_loss: 0.3640
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8787 - loss: 0.3312 - val_accuracy: 0.8833 - val_loss: 0.3329
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8835 - loss: 0.3170 - val_accuracy: 0.8828 - val_loss: 0.3311
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8908 - loss: 0.3041 - val_accuracy: 0.8795 - val_loss: 0.3248
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8916 - loss: 0.3014 - val_accuracy: 0.8860 - val_loss: 0.3155
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8944 - loss: 0.2889 - val_accuracy: 0.8815 - val_loss: 0.3283

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("Test accuracy:", test_acc)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.8746 - loss: 0.3480
# Test accuracy: 0.8745999932289124

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
index = 5   # you can change this number
img = x_test[index]

# %%
plt.imshow(img, cmap="gray")
plt.title("Test Image")
plt.show()

# %%
img = np.expand_dims(img, axis=0)

# %%
pred = model.predict(img)
predicted_class = np.argmax(pred)

print("Predicted class:", predicted_class)
print("True class:", y_test[index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted class: 1
# True class: 1
